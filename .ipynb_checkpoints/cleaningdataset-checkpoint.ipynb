# %%
import pandas as pd
import os

# %% [markdown]
# # ==============================
# # 1. Load Excel file
# # ==============================

# %%
file_path = "company_powerbi_dataset.xlsx"

# %%
df = pd.read_excel(file_path)
df
# Out:
#      EmployeeID     EmployeeName  Gender  Age  DepartmentID  \
# 0             1      Hamza Mirza  Female   54             2
# 1             2      Usman Iqbal    Male   42             4
# 2             3     Danish Javed  Female   50             2
# 3             4  Abdullah Sheikh  Female   53             6
# 4             5     Arham Sheikh    Male   56             7
# ..          ...              ...     ...  ...           ...
# 495         496       Hamza Raza  Female   30             3
# 496         497     Ibrahim Noor    Male   35             9
# 497         498     Hassan Aslam    Male   26             6
# 498         499    Sana Siddiqui  Female   24             9
# 499         500  Mehwish Qureshi  Female   29             2
#
#                  JobTitle   HireDate     Salary  PerformanceScore  \
# 0       Software Engineer 2022-08-13  114974.04                 2
# 1              Accountant 2025-08-01   88877.78                 5
# 2         Project Manager 2019-01-17   81592.94                 3
# 3    Operations Executive 2018-01-11  110474.55                 4
# 4            Data Analyst 2022-10-26   70972.33                 3
# ..                    ...        ...        ...               ...
# 495          Data Analyst 2019-10-03   97085.79                 4
# 496        Junior Analyst 2018-03-16  116348.86                 3
# 497     Finance Executive 2019-04-12   70135.22                 5
# 498      Business Analyst 2019-09-12   95326.00                 1
# 499            Accountant 2024-11-05  100250.94                 1
#
#      ExperienceYears EmploymentStatus     City   Region
# 0                 25           Active  Karachi    South
# 1                 23           Active  Karachi    South
# 2                 25           Active  Karachi    South
# 3                 25           Active   Lahore  Central
# 4                 25           Active  Karachi    South
# ..               ...              ...      ...      ...
# 495               14         Resigned   Lahore  Central
# 496               15           Active   Lahore  Central
# 497               10           Active   Lahore  Central
# 498                7           Active   Lahore  Central
# 499               13           Active  Karachi    South
#
# [500 rows x 13 columns]

# %%
print(df.head())
print(df.shape)
print(df.isnull().sum())
print("Duplicate rows:", df.duplicated().sum())
# Out:
#    EmployeeID     EmployeeName  Gender  Age  DepartmentID  \
# 0           1      Hamza Mirza  Female   54             2
# 1           2      Usman Iqbal    Male   42             4
# 2           3     Danish Javed  Female   50             2
# 3           4  Abdullah Sheikh  Female   53             6
# 4           5     Arham Sheikh    Male   56             7
#
#                JobTitle   HireDate     Salary  PerformanceScore  \
# 0     Software Engineer 2022-08-13  114974.04                 2
# 1            Accountant 2025-08-01   88877.78                 5
# 2       Project Manager 2019-01-17   81592.94                 3
# 3  Operations Executive 2018-01-11  110474.55                 4
# 4          Data Analyst 2022-10-26   70972.33                 3
#
#    ExperienceYears EmploymentStatus     City   Region
# 0               25           Active  Karachi    South
# 1               23           Active  Karachi    South
# 2               25           Active  Karachi    South
# 3               25           Active   Lahore  Central
# 4               25           Active  Karachi    South
# (500, 13)
# EmployeeID          0
# EmployeeName        0
# Gender              0
# Age                 0
# DepartmentID        0
# JobTitle            0
# HireDate            0
# Salary              0
# PerformanceScore    0
# ExperienceYears     0
# EmploymentStatus    0
# City                0
# Region              0
# dtype: int64
# Duplicate rows: 0

# %%
# Remove duplicate rows
df.drop_duplicates(inplace=True)

# %%
# Remove extra spaces from text columns
for col in df.select_dtypes(include="object").columns:
    df[col] = df[col].str.strip()
# Out:
# C:\Users\Sheheryar\AppData\Local\Temp\ipykernel_1472\3008722654.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for col in df.select_dtypes(include="object").columns:

# %%
# Convert date columns if available
if "SaleDate" in df.columns:
    df["SaleDate"] = pd.to_datetime(df["SaleDate"], errors="coerce")

# %%
# Check missing values after cleaning
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# EmployeeID          0
# EmployeeName        0
# Gender              0
# Age                 0
# DepartmentID        0
# JobTitle            0
# HireDate            0
# Salary              0
# PerformanceScore    0
# ExperienceYears     0
# EmploymentStatus    0
# City                0
# Region              0
# dtype: int64

# %%
print("\nDuplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
print("\nFinal Shape:", df.shape)
# Out:
# Final Shape: (500, 13)

# %%
df.to_excel(
    "company_powerbi_dataset_cleaned.xlsx",
    index=False
)

print("Cleaned file saved successfully!")
# Out:
# Cleaned file saved successfully!
